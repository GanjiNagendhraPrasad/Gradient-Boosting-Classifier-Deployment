# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df=pd.read_csv('/content/breast-cancer.csv')
df=df.drop(['id','Unnamed: 32'],axis=1)
df['diagnosis']=df['diagnosis'].map({'M':0,'B':1}).astype(int)
df.sample(10)
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 498          0       18.490         17.52          121.30     1068.0
# 24           0       16.650         21.38          110.00      904.6
# 337          0       18.770         21.43          122.90     1092.0
# 483          1       13.700         17.64           87.76      571.1
# 242          1       11.300         18.19           73.93      389.4
# 284          1       12.890         15.70           84.08      516.6
# 250          0       20.940         23.56          138.90     1364.0
# 426          1       10.480         14.98           67.49      333.6
# 152          1        9.731         15.34           63.78      300.2
# 151          1        8.219         20.70           53.27      203.9
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 498          0.10120           0.13170         0.14910              0.09183
# 24           0.11210           0.14570         0.15250              0.09170
# 337          0.09116           0.14020         0.10600              0.06090
# 483          0.09950           0.07957         0.04548              0.03160
# 242          0.09592           0.13250         0.15480              0.02854
# 284          0.07818           0.09580         0.11150              0.03390
# 250          0.10070           0.16060         0.27120              0.13100
# 426          0.09816           0.10130         0.06335              0.02218
# 152          0.10720           0.15990         0.41080              0.07857
# 151          0.09405           0.13050         0.13210              0.02168
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 498         0.1832  ...        22.750          22.88           146.40
# 24          0.1995  ...        26.460          31.56           177.00
# 337         0.1953  ...        24.540          34.37           161.10
# 483         0.1732  ...        14.960          23.53            95.78
# 242         0.2054  ...        12.580          27.96            87.16
# 284         0.1432  ...        13.900          19.69            92.12
# 250         0.2205  ...        25.580          27.00           165.30
# 426         0.1925  ...        12.130          21.57            81.41
# 152         0.2548  ...        11.020          19.49            71.04
# 151         0.2222  ...         9.092          29.72            58.08
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 498      1600.0           0.14120             0.3089           0.3533
# 24       2215.0           0.18050             0.3578           0.4695
# 337      1873.0           0.14980             0.4827           0.4634
# 483       686.5           0.11990             0.1346           0.1742
# 242       472.9           0.13470             0.4848           0.7436
# 284       595.6           0.09926             0.2317           0.3344
# 250      2010.0           0.12110             0.3172           0.6991
# 426       440.4           0.13270             0.2996           0.2939
# 152       380.5           0.12920             0.2772           0.8216
# 151       249.8           0.16300             0.4310           0.5381
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 498               0.16630          0.2510                  0.09445
# 24                0.20950          0.3613                  0.09564
# 337               0.20480          0.3679                  0.09870
# 483               0.09077          0.2518                  0.06960
# 242               0.12180          0.3308                  0.12970
# 284               0.10170          0.1999                  0.07127
# 250               0.21050          0.3126                  0.07849
# 426               0.09310          0.3020                  0.09646
# 152               0.15710          0.3108                  0.12590
# 151               0.07879          0.3322                  0.14860
#
# [10 rows x 31 columns]

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier
reg=GradientBoostingClassifier(n_estimators=5)
reg.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(n_estimators=5)

# %%
ans=reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
confusion_matrix(y_test,ans)
# Out:
# array([[40,  3],
#        [ 2, 69]])

# %%
print(classification_report(y_test,ans))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        43
#            1       0.96      0.97      0.97        71
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
accuracy_score(y_test,ans)
# Out:
# 0.956140350877193

# %%
import pickle

# %%
with open('gb.pkl','wb') as f:
  pickle.dump(reg,f)
